# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_blobs

# %%
centers= [[2,2,2],[7,7,7],[5,13,13]]

# %%
x, _ = make_blobs(n_samples=150,centers=centers,cluster_std=0.5)

# %%
x
# Out:
# array([[ 7.66973381,  6.77275036,  7.29796974],
#        [ 5.03312863, 13.43759854, 13.07172254],
#        [ 1.97176124,  1.83667311,  2.1966036 ],
#        [ 5.14746586, 12.85021745, 11.97691203],
#        [ 1.31208146,  1.49393865,  1.26860089],
#        [ 7.68649639,  7.02392853,  7.47625183],
#        [ 7.36672437,  6.56612556,  7.21354582],
#        [ 6.71799128,  6.90921853,  7.20828524],
#        [ 2.03695503,  1.02999396,  2.25937813],
#        [ 2.3991374 ,  2.04810955,  2.18628178],
#        [ 1.57936355,  2.2820528 ,  2.06298191],
#        [ 1.73311811,  2.31708426,  2.15409239],
#        [ 1.10358597,  2.03200789,  2.96213532],
#        [ 2.91463631,  2.1571735 ,  2.05768783],
#        [ 6.84364606,  6.89816972,  7.60595314],
#        [ 5.18684497, 12.79762645, 13.82357728],
#        [ 1.71096384,  2.24566397,  2.04216328],
#        [ 3.66597042, 13.3500678 , 12.50816272],
#        [ 4.99536492, 13.67580396, 12.82890129],
#        [ 4.70276297, 12.85301902, 12.83864201],
#        [ 1.55698431,  2.7414599 ,  1.28711482],
#        [ 2.47956728,  2.34573103,  1.64741183],
#        [ 4.88619678, 12.82390299, 14.41269434],
#        [ 7.81161699,  7.66424955,  7.43608895],
#        [ 2.10757698,  2.85172649,  1.53286553],
#        [ 1.59712883,  2.55805362,  1.71468869],
#        [ 5.87615342, 14.24978301, 13.58825294],
#        [ 2.63777348,  2.29472172,  2.29607379],
#        [ 7.2366807 ,  6.31621581,  7.02256926],
#        [ 4.81946458, 13.70665195, 13.46177143],
#        [ 5.1976559 , 12.96508937, 13.27217176],
#        [ 6.59617901,  6.08477617,  7.18275483],
#        [ 7.07794434,  6.63174596,  7.27074232],
#        [ 2.58978504,  2.49719427,  0.91602174],
#        [ 4.41578651, 13.32961843, 13.26414188],
#        [ 5.03796986, 12.7031768 , 13.21174404],
#        [ 7.42440404,  6.3511154 ,  5.98279503],
#        [ 6.91938116,  6.78594694,  7.12198959],
#        [ 5.29878125, 13.07277537, 12.78481579],
#        [ 6.67491268,  6.85313912,  6.3708575 ],
#        [ 6.02159757,  6.69636655,  6.93423655],
#        [ 4.81864805, 12.81837696, 12.14245666],
#        [ 1.48782526,  2.30098063,  1.72613191],
#        [ 1.82119882,  1.5557347 ,  2.00770003],
#        [ 5.40723227, 13.00566237, 13.3584546 ],
#        [ 4.89196709, 12.49692229, 12.93237451],
#        [ 5.35694502, 12.45111536, 12.7513169 ],
#        [ 6.93523198,  7.55537471,  6.60421303],
#        [ 4.28034973, 12.4159089 , 12.29670441],
#        [ 1.23696894,  2.35662124,  1.44354039],
#        [ 4.47325665, 13.54656037, 12.54960569],
#        [ 4.50209611, 13.11673085, 12.7347968 ],
#        [ 1.92220314,  1.21079172,  2.81955465],
#        [ 2.09954657,  2.40431372,  2.03192424],
#        [ 4.65001279, 12.82249277, 13.32852605],
#        [ 7.15264572,  6.37353447,  7.61363699],
#        [ 4.75814518, 13.31826278, 12.94585422],
#        [ 5.80981952, 13.36089226, 13.5087648 ],
#        [ 4.40322689, 13.43711932, 12.75390089],
#        [ 3.22334468,  2.59340518,  2.69574322],
#        [ 6.65187673,  6.82537963,  6.27715592],
#        [ 7.37414168,  7.79426215,  7.79910118],
#        [ 7.92549373,  7.34356031,  6.40248877],
#        [ 2.22701662,  1.56231642,  1.9969864 ],
#        [ 7.1491927 ,  7.58319894,  6.70482191],
#        [ 1.61359055,  1.94187382,  1.16625482],
#        [ 7.13724901,  7.4354593 ,  6.86762743],
#        [ 2.50357561,  1.64195011,  2.41953729],
#        [ 6.76233441,  6.6165911 ,  6.60466424],
#        [ 1.54849953,  2.34949015,  3.12852959],
#        [ 6.80511472,  6.94188935,  7.10274147],
#        [ 5.07000571, 13.75220573, 13.8079854 ],
#        [ 2.46729561,  2.84209018,  1.18143047],
#        [ 5.55243549, 12.64537034, 13.68421973],
#        [ 7.11529497,  6.1866835 ,  7.49539331],
#        [ 6.9223451 ,  7.33328979,  6.87571832],
#        [ 7.16877911,  6.56508024,  6.35709468],
#        [ 6.5805979 ,  7.13065993,  6.81438642],
#        [ 5.06121479, 12.96869714, 12.69104241],
#        [ 7.1370121 ,  6.75865018,  7.43693701],
#        [ 5.31743885, 13.67307446, 13.46163098],
#        [ 4.68232947, 12.64155501, 12.14566441],
#        [ 5.16648873, 12.74866292, 13.13192115],
#        [ 4.31660827, 12.51538985, 13.83819899],
#        [ 7.66610196,  7.62514586,  6.5152525 ],
#        [ 1.73232698,  1.33201438,  2.41147443],
#        [ 2.01338956,  1.48493478,  2.61221984],
#        [ 4.08484209, 12.56813621, 12.78931553],
#        [ 1.36348389,  1.85027461,  2.12425575],
#        [ 6.35091068,  7.43243167,  6.60895679],
#        [ 6.61606755,  7.25387827,  6.84039913]])

# %%
fig = plt.figure(figsize=(8,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(x[:,0],x[:,1],x[:,2])
plt.show()

# %%
from sklearn.cluster import MeanShift

# %%
ms= MeanShift()

# %%
ms.fit(x)
# Out:
# MeanShift()

# %%
y_pred= ms.fit_predict(x)

# %%
y_pred
# Out:
# array([0, 1, 2, 1, 2, 0, 0, 0, 2, 2, 2, 2, 2, 2, 0, 1, 2, 1, 1, 1, 2, 2,
#        1, 0, 2, 2, 1, 2, 0, 1, 1, 0, 0, 2, 1, 1, 0, 0, 1, 0, 0, 1, 2, 2,
#        1, 1, 1, 0, 1, 2, 1, 1, 2, 2, 1, 1, 1, 1, 0, 0, 1, 2, 2, 2, 0, 2,
#        0, 0, 2, 1, 0, 0, 0, 0, 2, 1, 2, 1, 2, 0, 2, 2, 1, 2, 0, 0, 1, 2,
#        2, 0, 1, 0, 0, 0, 2, 2, 2, 1, 1, 2, 0, 0, 0, 2, 2, 2, 2, 0, 1, 1,
#        1, 1, 1, 1, 0, 1, 1, 1, 2, 0, 0, 0, 2, 0, 2, 0, 2, 0, 2, 0, 1, 2,
#        1, 0, 0, 0, 0, 1, 0, 1, 1, 1, 1, 0, 2, 2, 1, 2, 0, 0], dtype=int64)

# %%
fig = plt.figure(figsize=(8,10))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(x[:,0],x[:,1],x[:,2],c=y_pred,cmap='rainbow')
plt.show()
